# %%
import pandas as pd

# %%
df=pd.read_excel(r"c:\Users\Student\Desktop\WITU COHORT 3\YEAR ONE\SEMITER ONE\Data science\data\dataset.xlsx")
print(df)
# Out:
#      S/N             student_names  age weight   height
# 0    1.0            Adokorac Nancy   20     74    177.8
# 1    2.0   Amutuhaire Faith Ahabwe   27     47   157.48
# 2    3.0     KWAGALA JOANNA VICTOR   21     54   185.42
# 3    4.0              mahoro cathy   23     30   185.42
# 4    5.0  Mbabazi Hawa Bint Edrisa   19     59   175.26
# 5    6.0       Nakanjako josephine   24     65   175.26
# 6    7.0            Nanteza Dorcus   21     69   157.48
# 7    8.0             Mbabazi Angel   19     57   167.64
# 8    9.0            Namara Racheal   19     55   154.94
# 9   10.0       Lwamulungi Sheillah   22     78   162.56
# 10   NaN           Nakawuka Sandra   25     60   175.26
# 11   NaN   Achola Gloria Fortunate   27     80   172.72
# 12   NaN             Nagawa Esther   21     58   188.42
# 13   NaN           wanjiku hananny   19     50    165.1
# 14   NaN            babirye Sandra   21     50   175.26
# 15   NaN          nakagga shanitah   21     50   175.26
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of      S/N             student_names  age weight   height
# 0    1.0            Adokorac Nancy   20     74    177.8
# 1    2.0   Amutuhaire Faith Ahabwe   27     47   157.48
# 2    3.0     KWAGALA JOANNA VICTOR   21     54   185.42
# 3    4.0              mahoro cathy   23     30   185.42
# 4    5.0  Mbabazi Hawa Bint Edrisa   19     59   175.26
# 5    6.0       Nakanjako josephine   24     65   175.26
# 6    7.0            Nanteza Dorcus   21     69   157.48
# 7    8.0             Mbabazi Angel   19     57   167.64
# 8    9.0            Namara Racheal   19     55   154.94
# 9   10.0       Lwamulungi Sheillah   22     78   162.56
# 10   NaN           Nakawuka Sandra   25     60   175.26
# 11   NaN   Achola Gloria Fortunate   27     80   172.72
# 12   NaN             Nagawa Esther   21     58   188.42
# 13   NaN           wanjiku hananny   19     50    165.1
# 14   NaN            babirye Sandra   21     50   175.26
# ...

# %%
df.tail
# Out:
# <bound method NDFrame.tail of      S/N             student_names  age weight   height
# 0    1.0            Adokorac Nancy   20     74    177.8
# 1    2.0   Amutuhaire Faith Ahabwe   27     47   157.48
# 2    3.0     KWAGALA JOANNA VICTOR   21     54   185.42
# 3    4.0              mahoro cathy   23     30   185.42
# 4    5.0  Mbabazi Hawa Bint Edrisa   19     59   175.26
# 5    6.0       Nakanjako josephine   24     65   175.26
# 6    7.0            Nanteza Dorcus   21     69   157.48
# 7    8.0             Mbabazi Angel   19     57   167.64
# 8    9.0            Namara Racheal   19     55   154.94
# 9   10.0       Lwamulungi Sheillah   22     78   162.56
# 10   NaN           Nakawuka Sandra   25     60   175.26
# 11   NaN   Achola Gloria Fortunate   27     80   172.72
# 12   NaN             Nagawa Esther   21     58   188.42
# 13   NaN           wanjiku hananny   19     50    165.1
# 14   NaN            babirye Sandra   21     50   175.26
# ...

# %%
import matplotlib.pyplot as plt

# %%
Height=df["height"]

# %%
Weight=df["weight"]

# %%
plt.plot("Height","Weight","o")
plt.xlabel("Height in cm")
plt.ylabel("Weight in kg")
plt.title("A scater plot of height and weight in cohort")
# Out:
# Text(0.5, 1.0, 'A scater plot of height and weight in cohort')

# %%
plt.xlabel("Height in cm")
# Out:
# Text(0.5, 0, 'Height in cm')

# %%
plt.ylabel("Weight in kg")
# Out:
# Text(0, 0.5, 'Weight in kg')

# %%
plt.title("A scater plot of height and weight in cohort")
# Out:
# Text(0.5, 1.0, 'A scater plot of height and weight in cohort')

# %% [markdown]
# PLOTING A VIOLING PLOT

# %%
isns.violinplot(x="Age",y="weight",data=df,inner=None)

# %%
df=pd.read_excel(r"c:\Users\Student\Desktop\WITU COHORT 3\YEAR ONE\SEMITER ONE\Data science\data\dataset.xlsx")
print(df)
# Out:
#      S/N             student_names  age weight   height
# 0    1.0            Adokorac Nancy   20     74    177.8
# 1    2.0   Amutuhaire Faith Ahabwe   27     47   157.48
# 2    3.0     KWAGALA JOANNA VICTOR   21     54   185.42
# 3    4.0              mahoro cathy   23     30   185.42
# 4    5.0  Mbabazi Hawa Bint Edrisa   19     59   175.26
# 5    6.0       Nakanjako josephine   24     65   175.26
# 6    7.0            Nanteza Dorcus   21     69   157.48
# 7    8.0             Mbabazi Angel   19     57   167.64
# 8    9.0            Namara Racheal   19     55   154.94
# 9   10.0       Lwamulungi Sheillah   22     78   162.56
# 10   NaN           Nakawuka Sandra   25     60   175.26
# 11   NaN   Achola Gloria Fortunate   27     80   172.72
# 12   NaN             Nagawa Esther   21     58   188.42
# 13   NaN           wanjiku hananny   19     50    165.1
# 14   NaN            babirye Sandra   21     50   175.26
# 15   NaN          nakagga shanitah   21     50   175.26
# ...

# %%
import seaborn as sns

# %%
sns.violinplot(x="age",y="weight",data=df,inner=None)
# Out:
# c:\Users\Student\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Student\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Student\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='age', ylabel='weight'>

# %%
sns.boxplot(x="age" ,y="weight",color="purple",data=df)
# Out:
# c:\Users\Student\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Student\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Student\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='age', ylabel='weight'>

# %%
sns.catplot(x="age" ,y="weight",color="grey",data=df)
# Out:
# c:\Users\Student\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Student\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Student\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...
